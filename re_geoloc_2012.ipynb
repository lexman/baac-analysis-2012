# %%
import functools
import locale
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# P:\WinPython-64bit-2.7.6.3\python-2.7.6.amd64\lib\site-packages\pandas\io\excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load databases

# %%
#ds = pd.read_csv('data2012/final2.csv', index_col=0)

# %%
reloc = pd.read_csv('data2012/regeoloc_incomplet.csv', index_col=0)

# %%
reloc.head(2)
# Out:
#                                 adr gps       lat     long  dep  insee_com  \
# num_acc
# 201200000001  33 Rue Roger Salengro   M  50.52928  2.93643  590      59110
# 201200000002           route de DON   M  50.53380  2.92738  590      59110
#
#              postal_code     nom_comm nom_dept          nom_region
# num_acc
# 201200000001       59630  BROUCKERQUE     NORD  NORD-PAS-DE-CALAIS
# 201200000002       59630  BROUCKERQUE     NORD  NORD-PAS-DE-CALAIS

# %%
ok = (np.abs(reloc.lat)>0) & (np.abs(reloc.long)>0)

# %%
todo = ~ok

# %%
adr = reloc['adr'].astype(str).str.lower().str.replace('nan', '')
postal_code = reloc['postal_code'].astype(str).str.lower().str.replace('nan', '')
nom_comm = reloc['nom_comm'].astype(str).str.lower().str.replace('nan', '')
nom_dept = reloc['nom_dept'].astype(str).str.lower().str.replace('nan', '')

# %%
adresse = adr + ' ' + postal_code + ' ' + nom_comm + ' ' + nom_dept

# %%
reloc['adresse'] = adresse

# %%
reloc[todo]
# Out:
#                                    adr  gps  lat  long  dep  insee_com  \
# num_acc
# 201200000206                       NaN    M    0     0  620      62420
# 201200000207            rue de la gare    M    0     0  620      62781
# 201200000216       718 rue de la place    M    0     0  620      62584
# 201200000218         668 rue d' Auchel    M    0     0  620      62473
# 201200000221             rue du boulan    M    0     0  620      62454
# 201200000224   4 rue Marcel caudevelle    M    0     0  620      62908
# 201200000225   4 Rue Marcel Caudevelle    M    0     0  620      62908
# 201200000230         RUE JACQUES CONTE    M    0     0  620      62773
# 201200000236                     d 237    M    0     0  620      62908
# 201200000244           rue victor HUGO    M    0     0  620      62705
# 201200000245           Rue Jean Jaures    M    0     0  620      62711
# 201200000247                     RD940    M    0     0  620      62264
# ...
