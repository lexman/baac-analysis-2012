# %%
import functools
import locale
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)

# %%
ds = pd.read_csv('data2012/final_brice_manual.csv', index_col=0)

# %%
ok = (np.abs(ds.lat)>0) & (np.abs(ds.long)>0)
todo = ~ok
np.sum(ok), len(ds)
# Out:
# (48650, 62250)

# %%
ds.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 201200000001 to 201200000005
# Data columns (total 52 columns):
# an                   5  non-null values
# mois                 5  non-null values
# jour                 5  non-null values
# hrmn                 5  non-null values
# lum                  5  non-null values
# agg                  5  non-null values
# int                  5  non-null values
# atm                  5  non-null values
# col                  5  non-null values
# com                  5  non-null values
# adr                  5  non-null values
# gps                  5  non-null values
# lat                  5  non-null values
# long                 5  non-null values
# dep                  5  non-null values
# gravite              5  non-null values
# nbimpliques          5  non-null values
# age_0                5  non-null values
# age_1                5  non-null values
# age_2                5  non-null values
# ...

# %%
manu = ds.lat>=65

# %%
manu.sum()
# Out:
# 1334

# %%
ds[manu][['lat', 'long']].head(2)
# Out:
#                   lat     long
# Num_Acc
# 201200003650  73.4516  1.81467
# 201200003661  73.4524  2.01980

# %%
ds.lat[manu] = 0
ds.long[manu] = 0

# %%
manu = ds.lat<=20

# %%
ds.lat[manu] = 0
ds.long[manu] = 0

# %%
manu.sum()
# Out:
# 17

# %% [raw]
# ds.lat[manu] = 10*ds.lat[manu]-30

# %%
ds.to_csv('data2012/final_brice_fix.csv', encoding='utf8')

# %%
#ds1 = pd.read_csv('data2012/final2.csv', index_col=0)
ds2 = pd.read_csv('data2012/final_brice2.csv', index_col=0)

# %%
ds2.lat[ds2.lat>0].describe()
# Out:
# count    47299.000000
# mean        47.308441
# std          2.194791
# min         41.410900
# 25%         45.703773
# 50%         48.209990
# 75%         48.872527
# max         51.051423
# dtype: float64

# %%
ds2.long.describe()
# Out:
# count    48650.000000
# mean         2.386027
# std          2.485810
# min         -4.731030
# 25%          0.986769
# 50%          2.361113
# 75%          3.908443
# max          9.532000
# dtype: float64

# %%
((np.abs(ds.lat)>0) & (np.abs(ds.long)>0)).sum(), len(ds)
# Out:
# (47299, 62250)

# %%
float(_[0])/_[1]
# Out:
# 0.7598232931726908

# %%
ds.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 201200000001 to 201200000005
# Data columns (total 52 columns):
# an                   5  non-null values
# mois                 5  non-null values
# jour                 5  non-null values
# hrmn                 5  non-null values
# lum                  5  non-null values
# agg                  5  non-null values
# int                  5  non-null values
# atm                  5  non-null values
# col                  5  non-null values
# com                  5  non-null values
# adr                  5  non-null values
# gps                  5  non-null values
# lat                  5  non-null values
# long                 5  non-null values
# dep                  5  non-null values
# gravite              5  non-null values
# nbimpliques          5  non-null values
# age_0                5  non-null values
# age_1                5  non-null values
# age_2                5  non-null values
# ...
