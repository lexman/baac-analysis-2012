# %%
import functools
import locale
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)

# %%
ds = pd.read_csv('data2012/final_brice2.csv', index_col=0)

# %%
dsc = pd.read_csv('data2012/caracteristiques.csv', index_col=0)

# %%
code_postal_slice = ds.postal_code.str.slice(0, 2)

# %%
ds[['dep', 'com', ']]

# %%
prob = ds.com<10

# %%
ds[prob].head(1)
# Out:
#               an  mois  jour  hrmn  lum  agg  int  atm  col  com  \
# Num_Acc
# 201200000181  12    12    13  2000    3    1    1    2    6    3
#
#                                    adr gps       lat     long  dep  gravite  \
# Num_Acc
# 201200000181  1189 R d Solre l Chateau   M  50.22569  4.09599  590        1
#
#               nbimpliques  age_0  age_1  age_2  age_3  age_4  hommes  femmes  \
# Num_Acc
# 201200000181            1      0      0      0      1      0       1       0
#
#               catr  circ  nbv  vosp  prof  plan  lartpc  larrout  surf  infra  \
# Num_Acc
# 201200000181     3     2    2     0     1     1       0       51     2      0
#
#               situ  env1  dayofweek postal_code     nom_comm nom_dept  \
# Num_Acc
# 201200000181     1     0          3       59247  HEM-LENGLET     NORD
#
#                       nom_region  sex  \
# Num_Acc
# 201200000181  NORD-PAS-DE-CALAIS    1
#
#                                                 details_usagers  \
# Num_Acc
# 201200000181  homme, 26 ans, blessé(e) hospitalisé(e), condu...
#
#                                   details_vehicules                datefull  \
# Num_Acc
# 201200000181  voiture, sans changement de direction  jeudi 13/12/2012 20:00
#
#                   atm_text                    lum_text             catr_text  \
# Num_Acc
# 201200000181  Pluie légère  Nuit sans éclairage public  Route départementale
#
#                        int_text infra_text col_text  \
# Num_Acc
# 201200000181  Hors intersection        NaN      NaN
#
#                                   approx
# Num_Acc
# 201200000181  Localisation approximative

# %%
dsc.head(1)
# Out:
#               an  mois  jour  hrmn  lum  agg  int  atm  col  com  \
# Num_Acc
# 201200000001  12     3    16  1930    5    5    1    1    6   11
#
#                                 adr gps      lat     long  dep
# Num_Acc
# 201200000001  33 Rue Roger Salengro   M  5052928  0293643  590
