# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotline inline
# Out:
# ERROR: Line magic function `%matplotline` not found.

# %%
pd.set_option('display.max_columns', None)

# %%
ds = pd.read_csv('data/data1.csv', delimiter=';')

# %%
ds.tail(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 454370 to 454371
# Data columns (total 41 columns):
# Unnamed: 0       2  non-null values
# org              2  non-null values
# lum              2  non-null values
# agg              2  non-null values
# int              2  non-null values
# atm              2  non-null values
# col              2  non-null values
# com              2  non-null values
# dep              2  non-null values
# catr             1  non-null values
# infra            1  non-null values
# voie             1  non-null values
# v1               1  non-null values
# v2               0  non-null values
# circ             1  non-null values
# nbv              1  non-null values
# pr               1  non-null values
# pr1              1  non-null values
# vosp             1  non-null values
# prof             1  non-null values
# plan             1  non-null values
# situ             1  non-null values
# ttue             2  non-null values
# ...

# %%
vehic = pd.read_csv('data/vehicules.csv', delimiter=',')

# %%
vehic.tail(2)
# Out:
#          numac  catv  vsp  app ass  anmc  momc  tuev  bgv  blv  indv
# 775420  454371    39    9    4   0  2000     5     0    1    0     0
# 775421  454372    38    0    5   0   NaN   NaN    26   24    0     0

# %%
dsm = pd.merge(ds, vehic, left_index=True, on='numac', how='left')
len(dsm)
# Out:
# 775422

# %%
dsm[dsm.addr_tot.notnull()].tail(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 454394 to 454395
# Data columns (total 51 columns):
# Unnamed: 0       2  non-null values
# org              2  non-null values
# lum              2  non-null values
# agg              2  non-null values
# int              2  non-null values
# atm              2  non-null values
# col              2  non-null values
# com              2  non-null values
# dep              2  non-null values
# catr             2  non-null values
# infra            2  non-null values
# voie             2  non-null values
# v1               2  non-null values
# v2               0  non-null values
# circ             2  non-null values
# nbv              2  non-null values
# pr               0  non-null values
# pr1              0  non-null values
# vosp             2  non-null values
# prof             2  non-null values
# plan             2  non-null values
# situ             2  non-null values
# ttue             2  non-null values
# ...
